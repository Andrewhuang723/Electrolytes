# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import os
import plotly.offline as py
import pandas as pd

# %% [markdown]
# ## You can access data file from .mol

# %%
! pip install py3Dmol

# %%
import rdkit
import rdkit.Chem as Chem
from rdkit.Chem import AllChem
import rdkit.Chem.Draw as Draw
# import py3Dmol

# %% [markdown]
# ### EC

# %%
smiles = "C1COC(=O)O1"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)
# Chem.MolToMolFile(mol, "./DMC/dmc.mol")

Draw.MolToImage(mol, size=(500, 500))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500>

# %% [markdown]
# ### EMC

# %%
smiles = "CCOC(=O)OC"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)
# Chem.MolToMolFile(mol, "./DMC/dmc.mol")

Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %% [markdown]
# ### PC

# %%
smiles = "CC1COC(=O)O1"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)
AllChem.UFFOptimizeMolecule(mol)

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

# Draw.MolToImage(mol, size=(2000, 2000))
MOL2LT("PC", mol, generate_system_file=True)

Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# Molcule PC was converted to PC.lt successfully.
# PC/system.lt generated.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %%
DATA2MOLTXT(molecule="PC")
# Out:
# Data file of PC has converted to molecule.txt

# %% [markdown]
# ### DMC

# %%
smiles = "COC(=O)OC"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)
AllChem.UFFOptimizeMolecule(mol)

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

# Draw.MolToImage(mol, size=(2000, 2000))
MOL2LT("DMC", mol, generate_system_file=True)
Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# Molcule DMC was converted to DMC.lt successfully.
# DMC/system.lt generated.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %%
DATA2MOLTXT(molecule="DMC")
# Out:
# Data file of DMC has converted to molecule.txt

# %% [markdown]
# ### DEC

# %%
smiles = "CCOC(=O)OCC"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %%
Chem.MolToMolFile(mol, "./DEC/DEC.mol")

# %% [markdown]
# ### EP

# %%
smiles = "CCC(=O)OCC"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %%
DATA2MOLTXT("EP")
# Out:
# Data file of EP has converted to molecule.txt

# %% [markdown]
# ### EA

# %%
smiles = "CCOC(=O)C"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

MOL2LT("EA", mol, generate_system_file=True)
Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# Molcule EA was converted to EA.lt successfully.
# EA/system.lt generated.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %%
DATA2MOLTXT(molecule="EA")
# Out:
# Data file of EA has converted to molecule.txt

# %% [markdown]
# ### VC

# %%
smiles = "C1=COC(=O)O1"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)
AllChem.UFFOptimizeMolecule(mol)
mol.GetConformer()

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

MOL2LT("VC", mol, generate_system_file=True)
Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# Molcule VC was converted to VC.lt successfully.
# VC/system.lt generated.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %%
DATA2MOLTXT(molecule="VC")
# Out:
# Data file of VC has converted to molecule.txt

# %% [markdown]
# ### DTD

# %%
smiles = "C1COS(=O)(=O)O1"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)
AllChem.UFFOptimizeMolecule(mol)
mol.GetConformer()

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

MOL2LT("DTD", mol, generate_system_file=True)
Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# Molcule DTD was converted to DTD.lt successfully.
# DTD/system.lt generated.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %%
DATA2MOLTXT("DTD")
# Out:
# Data file of DTD has converted to molecule.txt

# %% [markdown]
# ### TMSP

# %%
smiles = "C[Si](C)(C)CCC(=O)O"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)
AllChem.UFFOptimizeMolecule(mol)
mol.GetConformer()

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

# MOL2LT("TMSP", mol, generate_system_file=True)
Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# Molcule TMSP was converted to TMSP.lt successfully.
# TMSP/system.lt generated.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %%
DATA2MOLTXT("TMSP")
# Out:
# Data file of TMSP has converted to molecule.txt

# %% [markdown]
# ### MMDS

# %%
smiles = "C1OS(=O)(=O)CS(=O)(=O)O1"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)
AllChem.UFFOptimizeMolecule(mol)
mol.GetConformer()

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

MOL2LT("MMDS", mol, generate_system_file=True)
Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# Molcule MMDS was converted to MMDS.lt successfully.
# MMDS/system.lt generated.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %%
DATA2MOLTXT("MMDS")
# Out:
# Data file of MMDS has converted to molecule.txt

# %% [markdown]
# ### FEC

# %%
smiles = "C1C(OC(=O)O1)F"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)
AllChem.UFFOptimizeMolecule(mol)
mol.GetConformer()

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

MOL2LT("FEC", mol, generate_system_file=True)
Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# Molcule FEC was converted to FEC.lt successfully.
# FEC/system.lt generated.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %%
DATA2MOLTXT(molecule="FEC")
# Out:
# Data file of FEC has converted to molecule.txt

# %% [markdown]
# ### LiPF6

# %%
smiles = "[Li+].F[P-](F)(F)(F)(F)F"
# smiles = "F[P-](F)(F)(F)(F)F"

mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)
# Chem.MolToMolFile(mol, "./DMC/dmc.mol")

Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# [14:14:12] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# [14:14:12] UFFTYPER: Unrecognized charge state for atom: 1
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %%
DATA2MOLTXT("LiPF6")
# Out:
# Data file of LiPF6 has converted to molecule.txt

# %% [markdown]
# ### LiDFOB

# %%
smiles = "F[B-]1(OC(C(O1)=O)=O)F.[Li+]"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)
AllChem.UFFOptimizeMolecule(mol)
mol.GetConformer()

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

MOL2LT("LiDFOB", mol, generate_system_file=True)
Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# Molcule LiDFOB was converted to LiDFOB.lt successfully.
# LiDFOB/system.lt generated.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %% [markdown]
# ### LiFSI

# %%
smiles = "[Li+].[N-](S(=O)(=O)F)S(=O)(=O)F"
mol = Chem.MolFromSmiles(smiles)
mol = AllChem.AddHs(mol)
AllChem.EmbedMolecule(mol)
AllChem.UFFOptimizeMolecule(mol)
mol.GetConformer()

for atom in mol.GetAtoms():
    atom_label = f'{atom.GetSymbol()}{atom.GetIdx()+1}'
    atom.SetProp('atomLabel', atom_label)

MOL2LT("LiFSI", mol, generate_system_file=True)
Draw.MolToImage(mol, size=(2000, 2000))
# Out:
# Molcule LiFSI was converted to LiFSI.lt successfully.
# LiFSI/system.lt generated.
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2000x2000>

# %% [markdown]
# ## Convert .MOL to .lt file

# %%
system_block = """
write_once("Data Boundary") {
  -10 10 xlo xhi
  -10 10 ylo yhi
  -10 10 zlo zhi
}

# Create an input deck for LAMMPS.
write_once("In Init"){
 # Input variables.
 variable run    string ec   # output name
 variable ts     equal  1         # timestep
 variable temp   equal  300       # equilibrium temperature
 variable p      equal  1.        # equilibrium pressure
 variable d      equal  1000      # output frequency
 variable equi   equal  5000      # Equilibration steps
 variable prod   equal  30000     # Production steps

 # PBC (set them before the creation of the box).
 boundary p p p
}

# Run an NPT simulation.
write_once("In Run"){
 # Derived variables.
 variable tcouple equal \$\{ts\}*100
 variable pcouple equal \$\{ts\}*1000

 # Output.
 thermo          \$d
 thermo_style custom step etotal evdwl ecoul elong ebond eangle &
 edihed eimp ke pe temp press vol density cpu
 thermo_modify flush yes

 # Trajectory.
 dump TRJ all dcd \$d \$\{run\}.dcd
 dump_modify TRJ unwrap yes

 # Thermalisation and relaxation, NPT ensemble.
 timestep       \$\{ts\}
 fix             NPT all npt temp \$\{temp\} \$\{temp\} \$\{tcouple\} iso \$p \$p \$\{pcouple\}
 velocity all create \$\{temp\} 858096 dist gaussian
 # Short runs to update the PPPM settings as the box shinks.
 run    \$\{equi\} post no
 run    \$\{equi\} post no
 run    \$\{equi\} post no
 run    \$\{equi\}
 # From now on, the density shouldn't change too much.
 run    \$\{prod\}
 unfix NPT
}
"""

def MOL2LT(molecule_name, mol, generate_system_file=True):
    positions = mol.GetConformer().GetPositions()

    with open(f"./{molecule_name}/{molecule_name}.lt", "w") as f:

        header = f"# {molecule_name}.lt\n\n"
        f.write(header)

        f.write("import /Users/andrewhuang/Desktop/moltemplate/moltemplate/force_fields/oplsaa.lt\n")

        f.write(f"{molecule_name} inherits OPLSAA {{\n")
        f.write("\n")
        f.write(f"  write(\"Data Atoms\") {{\n")

        for atom in mol.GetAtoms():
            atom_postion = f"{positions[atom.GetIdx()][0]} {positions[atom.GetIdx()][1]} {positions[atom.GetIdx()][2]}"
            f.write(f"      $atom:{atom.GetIdx()+1}    $mol:.  @atom:      0.0     {atom_postion}\n")
        f.write(f'  }}\n')
        f.write('\n')


        f.write(f"  write(\"Data Bond List\") {{\n")
        for bond in mol.GetBonds():
            f.write(f"      $bond:{bond.GetIdx()+1}  $atom:{bond.GetBeginAtomIdx()+1}   $atom:{bond.GetEndAtomIdx()+1}\n")
        f.write(f'  }}\n')
        f.write('\n')

        f.write('}')
    
    print(f"Molcule {molecule_name} was converted to {molecule_name}.lt successfully.")


    if generate_system_file:
        with open(f"./{molecule_name}/system.lt", "w") as f:
            f.write(f"import \"{molecule_name}.lt\"\n")
            f.write("\n")
            f.write(f"{molecule_name} = new {molecule_name}[1].move(5.0, 0, 0)\n")
            f.write("       [1].move(0, 5.0, 0)\n")
            f.write("       [1].move(0, 0, 5.0)\n")
            f.write("\n")
            f.write(system_block)

    print(f"{molecule_name}/system.lt generated.")

# %% [markdown]
# ## Convert data (.data) to molecule file (.txt)

# %%
# molecule = "DMC"

def DATA2MOLTXT(molecule):

    Headers = [f"# {molecule} molecule\n"]
    Coords = []
    Types = []
    Charges = []
    Bonds = []
    Angles = []
    Dihedrals = []
    Impropers = []
    flag = None
    
    with open(f"./{molecule}/system_after.data", "r") as f:
        for i, line in enumerate(f.readlines()):      
            elements = line.strip()
            str_list = line.rsplit()
            if elements == "":
                continue
            if len(str_list) > 0 and (str_list[-1] in ["atoms", "bonds", "angles", "dihedrals", "impropers"]):
                Headers.append(elements+'\n')
            if flag == "Atoms" and len(str_list) > 1:
                Coords.append(f"{str_list[0]} {str_list[4]} {str_list[5]} {str_list[6]}\n")
                Types.append(f"{str_list[0]} {str_list[2]}\n")
                Charges.append(f"{str_list[0]} {str_list[3]}\n")
            elif flag == "Bonds" and len(str_list) > 1:
                Bonds.append(elements + '\n')
            elif flag == "Angles" and len(str_list) > 1:
                Angles.append(elements + '\n')
            elif flag == "Dihedrals" and len(str_list) > 1:
                Dihedrals.append(elements + '\n')
            elif flag == "Impropers" and len(str_list) > 1:
                Impropers.append(elements + '\n')
            else:
                pass
    
            if elements == "Atoms # full" or elements == "Atoms":
                flag = "Atoms"
                Coords.append('\nCoords\n\n')
                Charges.append('\nCharges\n\n')
                Types.append('\nTypes\n\n')
    
            elif elements == "Velocities":
                flag = None
            elif elements == "Bonds":
                flag = "Bonds"        
                Bonds.append('\nBonds\n\n')
            elif elements == "Angles":
                flag = "Angles"
                Angles.append('\nAngles\n\n')
            elif elements == "Dihedrals":
                flag = "Dihedrals"
                Dihedrals.append('\nDihedrals\n\n')
            elif elements == "Impropers":
                flag = "Impropers"
                Impropers.append("\nImpropers\n\n")
            else:
                pass
        
    
    
    
    with open(f"./{molecule}/molecule.txt", "w") as target:
        for block in [Headers, Coords, Charges, Types, Bonds, Angles, Dihedrals, Impropers]:
            for line in block:
                target.write(line)
    
    print(f"Data file of {molecule} has converted to molecule.txt")

# %% [markdown]
# ## Condcutivity
#
# $1 \frac{S}{m} = \frac{s^3\cdot (\frac{C}{s})^2}{kg\cdot m^2} \times \frac{1}{m} = \frac{s\cdot C^2}{kg\cdot m^3} = 10^{-18}\frac{fs\cdot C^2}{\AA^3\cdot g}$
#
# $k_B [=] 1.380649 \times 10^{-23} \frac{m^2\cdot kg}{s^2\cdot K}$
# $ = 1.380649 \times 10^{-30} \frac{\AA^2\cdot g}{fs^2\cdot K}$
#
# $e = 1.60217663 \times 10^{-19} C$

# %%
D_ca = 9.002e-6
D_an = 8.6e-6
e = 1.60217663e-19
kb = 1.380649e-30
T = 300
sigma = e**2 / (300 ** 3 * kb * 298) * (100 * 5 * D_ca + 100 * 6 * D_an)
sigma * 1e18
# Out:
# 0.0223243877176714

# %%
def calculate_conductivity(N_anions: list, D_anions: list, N_cations: list, D_cations: list, V: float, T=300) -> float:
    if len(D_anions) != len(N_anions):
        raise Exception("N_anions mismatched with the length of D_anions")
    if len(D_cations) != len(N_cations):
        raise Exception("N_caions mismatched with the length of D_cations")
    
    e = 1.60217663e-19
    kb = 1.380649e-30

    ND = sum([n_anion * d_anion for n_anion, d_anion in zip(N_anions, D_anions)]) + sum([n_cation * d_cation for n_cation, d_cation in zip(N_cations, D_cations)])
    
    sigma = e**2 / (V * kb * T) * ND
    return sigma * 1e18

# %%
def parse_MSD_log_file(filename):
    flag = False
    df_list = []
    with open(filename, "r") as f:
        for line in f.readlines():
            if line != "\n" and line.rsplit()[0] == "Step":
                flag = True
            if line != "\n" and line.rsplit()[0] == "Loop":
                flag = False
            if flag:
                df_list.append(line.rsplit())
    
    df = pd.DataFrame(df_list[1:])
    df.columns = df_list[0]
    return df.astype(float)

# %% [markdown]
# ## TESLA electrolytes

# %%
X56_df = parse_MSD_log_file(filename="./Diffuse/X56/MSD/log.lammps")
A49_df = parse_MSD_log_file(filename="./Diffuse/A49/MSD/log.lammps")
A48_df = parse_MSD_log_file(filename="./Diffuse/A48/MSD/log.lammps")
A47_df = parse_MSD_log_file(filename="./Diffuse/A47/MSD/log.lammps")
A46_df = parse_MSD_log_file(filename="./Diffuse/A46/MSD/log.lammps")

# %% [markdown]
# ### X56

# %%
X56_df["Conductivity"] = calculate_conductivity(N_anions=[64, 28], D_anions=[X56_df['v_FSI_ion_fitslope'], X56_df['v_PF6_ion_fitslope']],
                                                N_cations=[64 + 28], D_cations=[X56_df['v_Li_ion_fitslope']], V=11077694)

X56_df
# Out:
#          Step       Temp      Volume  Density  v_Li_ion_fitslope  \
# 0         0.0  298.66729  11077694.0  0.01812       1.666667e+18
# 1      1000.0  296.66345  11077694.0  0.01812       2.393677e-03
# 2      2000.0  297.48553  11077694.0  0.01812       2.242003e-03
# 3      3000.0  298.96602  11077694.0  0.01812       2.235355e-03
# 4      4000.0  297.93404  11077694.0  0.01812       2.215159e-03
# ..        ...        ...         ...      ...                ...
# 196  196000.0  297.91012  11077694.0  0.01812       2.498826e-03
# 197  197000.0  300.32384  11077694.0  0.01812       2.499934e-03
# 198  198000.0  299.08833  11077694.0  0.01812       2.501129e-03
# 199  199000.0  298.85609  11077694.0  0.01812       2.501441e-03
# 200  200000.0  300.09588  11077694.0  0.01812       2.502190e-03
#
#      v_PF6_ion_fitslope  v_FSI_ion_fitslope  Conductivity
# 0          1.666667e+18        1.666667e+18  1.715669e+21
# 1          4.311804e-04        4.216462e-04  1.450542e+00
# ...

# %%
X56_df["Conductivity"].iloc[1:].mean()
# Out:
# 1.1804468749008359

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=X56_df["Step"].iloc[1:], y=X56_df["v_Li_ion_fitslope"].iloc[1:]*1e-5, mode='lines+markers', name=r'$D_{Li+}$'))

fig.update_layout(title='Ion Diffusion Coefficient v.s Time step',
                  title_font=dict(size=50, family='Math'),                  
                  xaxis=dict(title="Time step (fs)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                  yaxis=dict(title="Diffusion Coefficient (m2/s)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                legend=dict(
                        font=dict(
                            size=20,  # Setting the font size of the legend
                            family='Courier New',  # Optional: setting the font type
                            color='black'  # Optional: setting the font color
                        ),
                    ))

fig.add_trace(go.Scatter(x=X56_df["Step"].iloc[1:], y=X56_df["v_PF6_ion_fitslope"].iloc[1:]*(1e-5), mode='lines+markers', name=r'$D_{PF6-}$'))
fig.add_trace(go.Scatter(x=X56_df["Step"].iloc[1:], y=X56_df["v_FSI_ion_fitslope"].iloc[1:]*(1e-5), mode='lines+markers', name=r'$D_{FSI-}$'))


plot_url = py.plot(fig, filename='latex', include_mathjax='cdn')
# Out:
# d:\anaconda3\envs\test\lib\site-packages\plotly\offline\offline.py:557: UserWarning:
#
# Your filename `latex` didn't end with .html. Adding .html to the end of your file.

# %% [markdown]
# ### A49

# %%
A49_df["Conductivity"] = calculate_conductivity(N_anions=[34, 67], D_anions=[A49_df['v_FSI_ion_fitslope'], A49_df['v_PF6_ion_fitslope']],
                                                N_cations=[34 + 67], D_cations=[A49_df['v_Li_ion_fitslope']], V=12832358.0)

A49_df
# Out:
#          Step       Temp      Volume   Density  v_Li_ion_fitslope  \
# 0         0.0  299.51637  12832358.0  0.015675       1.666667e+18
# 1      1000.0  297.81290  12832358.0  0.015675       1.398242e-03
# 2      2000.0  298.82214  12832358.0  0.015675       1.477256e-03
# 3      3000.0  299.95294  12832358.0  0.015675       1.467414e-03
# 4      4000.0  299.17487  12832358.0  0.015675       1.350909e-03
# ..        ...        ...         ...       ...                ...
# 196  196000.0  297.57136  12832358.0  0.015675       1.751979e-03
# 197  197000.0  296.12278  12832358.0  0.015675       1.749327e-03
# 198  198000.0  301.73463  12832358.0  0.015675       1.747017e-03
# 199  199000.0  299.43492  12832358.0  0.015675       1.744320e-03
# 200  200000.0  298.43734  12832358.0  0.015675       1.740970e-03
#
#      v_PF6_ion_fitslope  v_FSI_ion_fitslope  Conductivity
# 0          1.666667e+18        1.666667e+18  1.625960e+21
# ...

# %%
A49_df["Conductivity"].iloc[1:].mean()
# Out:
# 0.8546690361261199

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=A49_df["Step"].iloc[1:], y=A49_df["v_Li_ion_fitslope"].iloc[1:]*1e-5, mode='lines+markers', name=r'$D_{Li+}$'))

fig.update_layout(title='Ion Diffusion Coefficient v.s Time step',
                  title_font=dict(size=50, family='Math'),                  
                  xaxis=dict(title="Time step (fs)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                  yaxis=dict(title="Diffusion Coefficient (m2/s)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                legend=dict(
                        font=dict(
                            size=20,  # Setting the font size of the legend
                            family='Courier New',  # Optional: setting the font type
                            color='black'  # Optional: setting the font color
                        ),
                    ))

fig.add_trace(go.Scatter(x=A49_df["Step"].iloc[1:], y=A49_df["v_PF6_ion_fitslope"].iloc[1:]*(1e-5), mode='lines+markers', name=r'$D_{PF6-}$'))
fig.add_trace(go.Scatter(x=A49_df["Step"].iloc[1:], y=A49_df["v_FSI_ion_fitslope"].iloc[1:]*(1e-5), mode='lines+markers', name=r'$D_{FSI-}$'))


plot_url = py.plot(fig, filename='latex', include_mathjax='cdn')
# Out:
# d:\anaconda3\envs\test\lib\site-packages\plotly\offline\offline.py:557: UserWarning:
#
# Your filename `latex` didn't end with .html. Adding .html to the end of your file.

# %% [markdown]
# ### A48

# %%
A48_df["Conductivity"] = calculate_conductivity(N_anions=[35, 70], D_anions=[A48_df['v_FSI_ion_fitslope'], A48_df['v_PF6_ion_fitslope']],
                                                N_cations=[35 + 70], D_cations=[A48_df['v_Li_ion_fitslope']], V=12983636.0)

A48_df
# Out:
#          Step       Temp      Volume   Density  v_Li_ion_fitslope  \
# 0         0.0  299.32395  12983636.0  0.015575       1.666667e+18
# 1      1000.0  301.59022  12983636.0  0.015575       1.312365e-03
# 2      2000.0  300.65351  12983636.0  0.015575       1.222895e-03
# 3      3000.0  295.38388  12983636.0  0.015575       1.334345e-03
# 4      4000.0  301.20323  12983636.0  0.015575       1.559944e-03
# ..        ...        ...         ...       ...                ...
# 196  196000.0  298.69792  12983636.0  0.015575       1.444930e-03
# 197  197000.0  296.21849  12983636.0  0.015575       1.447085e-03
# 198  198000.0  295.11209  12983636.0  0.015575       1.449272e-03
# 199  199000.0  297.60333  12983636.0  0.015575       1.451603e-03
# 200  200000.0  298.29833  12983636.0  0.015575       1.453739e-03
#
#      v_PF6_ion_fitslope  v_FSI_ion_fitslope  Conductivity
# 0          1.666667e+18        1.666667e+18  1.670660e+21
# ...

# %%
A48_df["Conductivity"].iloc[1:].mean()
# Out:
# 0.8487845880432494

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=A48_df["Step"].iloc[1:], y=A48_df["v_Li_ion_fitslope"].iloc[1:]*1e-5, mode='lines+markers', name=r'$D_{Li+}$'))

fig.update_layout(title='Ion Diffusion Coefficient v.s Time step',
                  title_font=dict(size=50, family='Math'),                  
                  xaxis=dict(title="Time step (fs)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                  yaxis=dict(title="Diffusion Coefficient (m2/s)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                legend=dict(
                        font=dict(
                            size=20,  # Setting the font size of the legend
                            family='Courier New',  # Optional: setting the font type
                            color='black'  # Optional: setting the font color
                        ),
                    ))

fig.add_trace(go.Scatter(x=A48_df["Step"].iloc[1:], y=A48_df["v_PF6_ion_fitslope"].iloc[1:]*(1e-5), mode='lines+markers', name=r'$D_{PF6-}$'))
fig.add_trace(go.Scatter(x=A48_df["Step"].iloc[1:], y=A48_df["v_FSI_ion_fitslope"].iloc[1:]*(1e-5), mode='lines+markers', name=r'$D_{FSI-}$'))


plot_url = py.plot(fig, filename='latex', include_mathjax='cdn')
# Out:
# d:\anaconda3\envs\test\lib\site-packages\plotly\offline\offline.py:557: UserWarning:
#
# Your filename `latex` didn't end with .html. Adding .html to the end of your file.

# %% [markdown]
# ### A47

# %%
A47_df["Conductivity"] = calculate_conductivity(N_anions=[35, 70, 4], D_anions=[A47_df['v_FSI_ion_fitslope'], A47_df['v_PF6_ion_fitslope'], A47_df['v_DFOB_ion_fitslope']],
                                                N_cations=[35 + 70 + 4], D_cations=[A47_df['v_Li_ion_fitslope']], V=13248135.0)

A47_df
# Out:
#          Step       Temp      Volume   Density  v_Li_ion_fitslope  \
# 0         0.0  297.83319  13248135.0  0.015196       1.666667e+18
# 1      1000.0  299.19658  13248135.0  0.015196       1.665699e-03
# 2      2000.0  299.39206  13248135.0  0.015196       1.832916e-03
# 3      3000.0  299.77238  13248135.0  0.015196       1.796027e-03
# 4      4000.0  301.45855  13248135.0  0.015196       1.793560e-03
# ..        ...        ...         ...       ...                ...
# 196  196000.0  296.16742  13248135.0  0.015196       1.295608e-03
# 197  197000.0  296.22415  13248135.0  0.015196       1.294627e-03
# 198  198000.0  296.54160  13248135.0  0.015196       1.294054e-03
# 199  199000.0  298.39755  13248135.0  0.015196       1.294034e-03
# 200  200000.0  299.19092  13248135.0  0.015196       1.293851e-03
#
#      v_PF6_ion_fitslope  v_FSI_ion_fitslope  v_DFOB_ion_fitslope  Conductivity
# 0          1.666667e+18        1.666667e+18         1.666667e+18  1.699678e+21
# ...

# %%
A47_df["Conductivity"].iloc[1:].mean()
# Out:
# 0.8528852130754839

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=A47_df["Step"].iloc[1:], y=A47_df["v_Li_ion_fitslope"].iloc[1:]*1e-5, mode='lines+markers', name=r'$D_{Li+}$'))

fig.update_layout(title='Ion Diffusion Coefficient v.s Time step',
                  title_font=dict(size=50, family='Math'),                  
                  xaxis=dict(title="Time step (fs)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                  yaxis=dict(title="Diffusion Coefficient (m2/s)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                legend=dict(
                        font=dict(
                            size=20,  # Setting the font size of the legend
                            family='Courier New',  # Optional: setting the font type
                            color='black'  # Optional: setting the font color
                        ),
                    ))

fig.add_trace(go.Scatter(x=A47_df["Step"].iloc[1:], y=A47_df["v_PF6_ion_fitslope"].iloc[1:]*(1e-5), mode='lines+markers', name=r'$D_{PF6-}$'))
fig.add_trace(go.Scatter(x=A47_df["Step"].iloc[1:], y=A47_df["v_FSI_ion_fitslope"].iloc[1:]*(1e-5), mode='lines+markers', name=r'$D_{FSI-}$'))
fig.add_trace(go.Scatter(x=A47_df["Step"].iloc[1:], y=A47_df["v_DFOB_ion_fitslope"].iloc[1:]*(1e-5), mode='lines+markers', name=r'$D_{DFOB-}$'))
plot_url = py.plot(fig, filename='latex', include_mathjax='cdn')
# Out:
# d:\anaconda3\envs\test\lib\site-packages\plotly\offline\offline.py:557: UserWarning:
#
# Your filename `latex` didn't end with .html. Adding .html to the end of your file.

# %% [markdown]
# ### A46

# %%
A46_df["Conductivity"] = calculate_conductivity(N_anions=[35, 70], D_anions=[A46_df['v_FSI_ion_fitslope'], A46_df['v_PF6_ion_fitslope']],
                                                N_cations=[35 + 70], D_cations=[A46_df['v_Li_ion_fitslope']], V=13106214)

A46_df
# Out:
#          Step       Temp  v_Li_ion_fitslope  v_PF6_ion_fitslope  \
# 0         0.0  297.16682       1.666667e+18        1.666667e+18
# 1      1000.0  297.10823       1.353360e-03        3.797147e-04
# 2      2000.0  295.73945       1.780389e-03        3.132685e-04
# 3      3000.0  297.91657       1.658369e-03        2.802767e-04
# 4      4000.0  299.26151       1.624531e-03        2.572912e-04
# ..        ...        ...                ...                 ...
# 196  196000.0  296.21575       1.404595e-03        2.041977e-04
# 197  197000.0  298.62485       1.401929e-03        2.036224e-04
# 198  198000.0  298.74163       1.398866e-03        2.029545e-04
# 199  199000.0  300.88653       1.396550e-03        2.022834e-04
# 200  200000.0  296.26012       1.394288e-03        2.015740e-04
#
#      v_FSI_ion_fitslope  Conductivity
# 0          1.666667e+18  1.655034e+21
# 1          4.777586e-04  8.767162e-01
# 2          3.039272e-04  1.037977e+00
# 3          3.062392e-04  9.668548e-01
# ...

# %%
A46_df["Conductivity"].iloc[1:].mean()
# Out:
# 0.8338946537571063

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=A46_df["Step"].iloc[1:], y=A46_df["v_Li_ion_fitslope"].iloc[1:]*1e-5, mode='lines+markers', name=r'$D_{Li+}$'))

fig.update_layout(title='Ion Diffusion Coefficient v.s Time step',
                  title_font=dict(size=50, family='Math'),                  
                  xaxis=dict(title="Time step (fs)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                  yaxis=dict(title="Diffusion Coefficient (m2/s)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                legend=dict(
                        font=dict(
                            size=20,  # Setting the font size of the legend
                            family='Courier New',  # Optional: setting the font type
                            color='black'  # Optional: setting the font color
                        ),
                    ))

fig.add_trace(go.Scatter(x=A46_df["Step"].iloc[1:], y=A46_df["v_PF6_ion_fitslope"].iloc[1:]*(1e-5), mode='lines+markers', name=r'$D_{PF6-}$'))
fig.add_trace(go.Scatter(x=A46_df["Step"].iloc[1:], y=A46_df["v_FSI_ion_fitslope"].iloc[1:]*(1e-5), mode='lines+markers', name=r'$D_{FSI-}$'))


plot_url = py.plot(fig, filename='latex', include_mathjax='cdn')
# Out:
# d:\anaconda3\envs\test\lib\site-packages\plotly\offline\offline.py:557: UserWarning:
#
# Your filename `latex` didn't end with .html. Adding .html to the end of your file.

# %% [markdown]
# ### Results

# %% [markdown]
# #### Diffusion coefficient

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=A47_df["Step"].iloc[1:], y=A47_df["v_Li_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='brown',
                                    symbol='circle',
                                    line=dict(width=1)
                         ),
                         name=r'$A47: D_{Li+}$'))
fig.add_trace(go.Scatter(x=A47_df["Step"].iloc[1:], y=A47_df["v_PF6_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='brown',
                                    symbol='diamond',
                                    line=dict(width=1)
                         ),
                         name=r'$A47: D_{PF6-}$'))
fig.add_trace(go.Scatter(x=A47_df["Step"].iloc[1:], y=A47_df["v_FSI_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='brown',
                                    symbol='star',
                                    line=dict(width=1)
                         ),
                         name=r'$A47: D_{FSI-}$'))

fig.add_trace(go.Scatter(x=A47_df["Step"].iloc[1:], y=A47_df["v_DFOB_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='brown',
                                    symbol='cross',
                                    line=dict(width=1)
                         ),
                         name=r'$A47: D_{DFOB-}$'))

fig.add_trace(go.Scatter(x=A48_df["Step"].iloc[1:], y=A48_df["v_Li_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='darkorange',
                                    symbol='circle',
                                    line=dict(width=1)
                         ),
                         name=r'$A48: D_{Li+}$'))
fig.add_trace(go.Scatter(x=A48_df["Step"].iloc[1:], y=A48_df["v_PF6_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='darkorange',
                                    symbol='diamond',
                                    line=dict(width=1)
                         ),
                         name=r'$A48: D_{PF6-}$'))
fig.add_trace(go.Scatter(x=A48_df["Step"].iloc[1:], y=A48_df["v_FSI_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='darkorange',
                                    symbol='star',
                                    line=dict(width=1)
                         ),
                         name=r'$A48: D_{FSI-}$'))


fig.add_trace(go.Scatter(x=A49_df["Step"].iloc[1:], y=A49_df["v_Li_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='teal',
                                    symbol='circle',
                                    line=dict(width=1)
                         ),
                         name=r'$A49: D_{Li+}$'))
fig.add_trace(go.Scatter(x=A49_df["Step"].iloc[1:], y=A49_df["v_PF6_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='teal',
                                    symbol='diamond',
                                    line=dict(width=1)
                         ),
                         name=r'$A49: D_{PF6-}$'))
fig.add_trace(go.Scatter(x=A49_df["Step"].iloc[1:], y=A49_df["v_FSI_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='teal',
                                    symbol='star',
                                    line=dict(width=1)
                         ),
                         name=r'$A49: D_{FSI-}$'))

fig.add_trace(go.Scatter(x=X56_df["Step"].iloc[1:], y=X56_df["v_Li_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='navy',
                                    symbol='circle',
                                    line=dict(width=1)
                         ),
                         name=r'$X56: D_{Li+}$'))
fig.add_trace(go.Scatter(x=X56_df["Step"].iloc[1:], y=X56_df["v_PF6_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='navy',
                                    symbol='diamond',
                                    line=dict(width=1)
                         ),
                         name=r'$X56: D_{PF6-}$'))
fig.add_trace(go.Scatter(x=X56_df["Step"].iloc[1:], y=X56_df["v_FSI_ion_fitslope"].iloc[1:]*1e-5, 
                         mode='markers',
                         marker=dict(
                                    size=8,
                                    color='navy',
                                    symbol='star',
                                    line=dict(width=1)
                         ),
                         name=r'$X56: D_{FSI-}$'))


fig.update_layout(title='Li+ Diffusion Coefficient v.s Time step',
                  title_font=dict(size=50, family='Math'),                  
                  xaxis=dict(title="Time step (fs)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                  yaxis=dict(title="Diffusion coefficient (m2/s)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                legend=dict(
                        font=dict(
                            size=20,  # Setting the font size of the legend
                            family='Courier New',  # Optional: setting the font type
                            color='black'  # Optional: setting the font color
                        ),
                    ))

plot_url = py.plot(fig, filename='latex', include_mathjax='cdn')
# Out:
# d:\anaconda3\envs\test\lib\site-packages\plotly\offline\offline.py:557: UserWarning:
#
# Your filename `latex` didn't end with .html. Adding .html to the end of your file.

# %% [markdown]
# #### Conductivity

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=A47_df["Step"].iloc[1:], y=A47_df["Conductivity"].iloc[1:], mode='lines+markers',
                         marker=dict(
                                    size=8,
                                    color='brown',
                                    symbol='circle',
                                    line=dict(width=1)
                         ),
                          name=r'$A47: \sigma_e$'))

fig.add_trace(go.Scatter(x=A48_df["Step"].iloc[1:], y=A48_df["Conductivity"].iloc[1:], mode='lines+markers',
                         marker=dict(
                                    size=8,
                                    color='darkorange',
                                    symbol='circle',
                                    line=dict(width=1)
                         ),
                          name=r'$A48: \sigma_e$'))

fig.add_trace(go.Scatter(x=A49_df["Step"].iloc[1:], y=A49_df["Conductivity"].iloc[1:], mode='lines+markers',
                         marker=dict(
                                    size=8,
                                    color='teal',
                                    symbol='circle',
                                    line=dict(width=1)
                         ),
                          name=r'$A49: \sigma_e$'))

fig.add_trace(go.Scatter(x=X56_df["Step"].iloc[1:], y=X56_df["Conductivity"].iloc[1:], mode='lines+markers',
                         marker=dict(
                                    size=8,
                                    color='navy',
                                    symbol='circle',
                                    line=dict(width=1)
                         ),
                          name=r'$X56: \sigma_e$'))

fig.update_layout(title='Ion Conductivity v.s Time step',
                  title_font=dict(size=50, family='Math'),                  
                  xaxis=dict(title='Time step (fs)',
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                  yaxis=dict(title="Ion Conductivity (S/m)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                legend=dict(
                        font=dict(
                            size=20,  # Setting the font size of the legend
                            family='Courier New',  # Optional: setting the font type
                            color='black'  # Optional: setting the font color
                        ),
                    ))

# fig.add_trace(go.Scatter(x=A49_df["Step"].iloc[1:], y=A49_df["Conductivity"].iloc[1:], mode='lines+markers', name=r'$A49: \sigma_e$'))
# fig.add_trace(go.Scatter(x=X56_df["Step"].iloc[1:], y=X56_df["Conductivity"].iloc[1:], mode='lines+markers', name=r'$X56: \sigma_e$'))



plot_url = py.plot(fig, filename='latex', include_mathjax='cdn')
# Out:
# d:\anaconda3\envs\test\lib\site-packages\plotly\offline\offline.py:557: UserWarning:
#
# Your filename `latex` didn't end with .html. Adding .html to the end of your file.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## T8 Electrolytes

# %%
T8_df = parse_MSD_log_file(filename="./Diffuse/T8/MSD2/log.lammps")

T8_df["Conductivity"] = calculate_conductivity(N_anions=[157, 12], D_anions=[T8_df['v_PF6_ion_fitslope'], T8_df['v_DFOB_ion_fitslope']],
                                                N_cations=[157 + 12], D_cations=[T8_df['v_Li_ion_fitslope']], V=166411.52)

T8_df
# Out:
#          Step       Temp     Volume   Density  v_Li_ion_fitslope  \
# 0         0.0  297.46736  166411.52  0.959345       1.666667e+18
# 1      1000.0  297.90447  166411.52  0.959345       9.501095e-05
# 2      2000.0  299.34167  166411.52  0.959345       2.775021e-04
# 3      3000.0  299.64159  166411.52  0.959345       3.373736e-04
# 4      4000.0  294.00971  166411.52  0.959345       3.242697e-04
# ..        ...        ...        ...       ...                ...
# 196  196000.0  296.27502  166411.52  0.959345       1.323779e-04
# 197  197000.0  296.02254  166411.52  0.959345       1.322540e-04
# 198  198000.0  297.38368  166411.52  0.959345       1.321806e-04
# 199  199000.0  296.53335  166411.52  0.959345       1.320832e-04
# 200  200000.0  295.98453  166411.52  0.959345       1.321081e-04
#
#      v_PF6_ion_fitslope  v_DFOB_ion_fitslope  Conductivity
# 0          1.666667e+18         1.666667e+18  2.097965e+23
# 1         -5.867427e-06         2.251996e-04  6.643248e+00
# ...

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=T8_df["Step"].iloc[1:], y=T8_df["Conductivity"].iloc[1:], mode='lines+markers',
                         marker=dict(
                                    size=8,
                                    color='brown',
                                    symbol='circle',
                                    line=dict(width=1)
                         ),
                          name=r'$T8: \sigma_e$'))

fig.update_layout(title='Ion Conductivity v.s Time step',
                  title_font=dict(size=50, family='Math'),                  
                  xaxis=dict(title='Time step (fs)',
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                  yaxis=dict(title="Ion Conductivity (S/m)",
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                legend=dict(
                        font=dict(
                            size=20,  # Setting the font size of the legend
                            family='Courier New',  # Optional: setting the font type
                            color='black'  # Optional: setting the font color
                        ),
                    ))

# fig.add_trace(go.Scatter(x=A49_df["Step"].iloc[1:], y=A49_df["Conductivity"].iloc[1:], mode='lines+markers', name=r'$A49: \sigma_e$'))
# fig.add_trace(go.Scatter(x=X56_df["Step"].iloc[1:], y=X56_df["Conductivity"].iloc[1:], mode='lines+markers', name=r'$X56: \sigma_e$'))



plot_url = py.plot(fig, filename='latex', include_mathjax='cdn')
# Out:
# d:\anaconda3\envs\test\lib\site-packages\plotly\offline\offline.py:557: UserWarning:
#
# Your filename `latex` didn't end with .html. Adding .html to the end of your file.

# %% [markdown]
# ## Mixing EC & DEC

# %% [markdown]
# ### Calculate entropy

# %%
Step = []
Entropy = []
with open("./Mixing/equilibration/dump.lammpstrj", "r") as f:
    flag = None
    batch = []
    cnt = 0
    for i, line in enumerate(f.readlines()):
        if line == "ITEM: TIMESTEP\n":
            flag = "step"
            if len(batch) > 0:
                Entropy.append(batch) 
                batch = []
            continue

        if line == "ITEM: ATOMS x y z type id c_my_entropy\n":
            flag = "entropy"
            continue

        if flag == "step":
            Step.append(int(line.rsplit()[0]))
            flag = None
        
        if flag == "entropy":
            s = line.rsplit()[-1]
            if s != 'nan':
                batch.append(float(s))

Entropy.append(batch)
Entropy = list(map(lambda x: sum(x) * -1, Entropy))

# pmma_entropy = 34.98 * 1
dec_entropy = 119.2223 * 100
ec_entropy = 108.4058 * 100

delta_S_mix = list(map(lambda x: (x / (4.2) - (dec_entropy+ec_entropy))/1000, Entropy)) # cal/mol K

# %% [markdown]
# #### Ideal solution

# %%
ideal_delta_S_mix = 201 * 8.314 * (1/201 * np.log(1/201) + 100/201 * np.log(100/201) * 2) / 4.2
ideal_delta_S_mix
# Out:
# -286.8928792536276

# %% [markdown]
# ### Enthalpy

# %%
import numpy as np

Enthalpy = []
with open("./Mixing/equilibration/log.lammps", "r") as f:
    for i, line in enumerate(f.readlines()):
        if i >= 4144 and i <= 4204:
            enthalpy = float(line.rsplit()[2])
            Enthalpy.append(enthalpy)



# pmma_enthalpy = 233.7869 * 1
dec_enthalpy = 12.789 * 100
ec_enthalpy = 7.1734 * 100

delta_H_mix = list(map(lambda x: x - (dec_enthalpy+ec_enthalpy), Enthalpy))
delta_H_mix = np.array(delta_H_mix[1:]).reshape(-1, 2).mean(axis=1)

# %%
delta_S_mix[-1]
# Out:
# -11.308644738095225

# %% [markdown]
# ### Gibbs free energy

# %%
delta_G_mix = np.array(delta_H_mix) + 300 * np.array(delta_S_mix[1:])

# %% [markdown]
# ### Solubility

# %%
delta_H_fus = -682
R = 8.314
T_m = 240 + 273
T = 300
x_sol = np.exp(delta_H_fus / (R* T_m) * (1 - (T / T_m)) - delta_G_mix[-1] / (R*T))
x_sol
# Out:
# 0.6455181957193957

# %% [markdown]
# ### Plot

# %%
fig = go.Figure()

# fig.add_trace(go.Scatter(x=Step[1:], y=list(map(sum, Entropy[1:])), mode='lines', name='Line plot'))
fig.add_trace(go.Scatter(x=Step[1:], y=delta_H_mix, mode='lines+markers', name=r'$\Delta H_{mix}$'))

fig.update_layout(title='EC/DEC Mixing v.s Time step\n',
                  title_font=dict(size=50, family='Math'),
                  xaxis=dict(title=r'$ Time step (fs)$',
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                  yaxis=dict(title=r'$Energy(\frac{kcal}{mol})$',
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                legend=dict(
                        font=dict(
                            size=20,  # Setting the font size of the legend
                            family='Courier New',  # Optional: setting the font type
                            color='black'  # Optional: setting the font color
                        ),
                    )
)

fig.add_trace(go.Scatter(x=Step[1:], y=np.array(delta_S_mix) * 300 * -1, mode='lines+markers', name=r'$T \Delta S_{mix}$'))
fig.add_trace(go.Scatter(x=Step[1:], y=delta_G_mix, mode='lines+markers', name=r'$\Delta G_{mix}$'))



plot_url = py.plot(fig, filename='latex', include_mathjax='cdn')
# Out:
# /Users/andrewhuang/opt/anaconda3/envs/battery/lib/python3.9/site-packages/plotly/offline/offline.py:562: UserWarning:
#
# Your filename `latex` didn't end with .html. Adding .html to the end of your file.

# %% [markdown]
# ## Mixing PMMA and Solvents

# %% [markdown]
# ### Entropy

# %%
Step = []
Entropy = []
with open("./MixingPMMA/equilibration/dump.lammpstrj", "r") as f:
    flag = None
    batch = []
    cnt = 0
    for i, line in enumerate(f.readlines()):
        if line == "ITEM: TIMESTEP\n":
            flag = "step"
            if len(batch) > 0:
                Entropy.append(batch) 
                batch = []
            continue

        if line == "ITEM: ATOMS x y z type id c_my_entropy\n":
            flag = "entropy"
            continue

        if flag == "step":
            Step.append(int(line.rsplit()[0]))
            flag = None
        
        if flag == "entropy":
            s = line.rsplit()[-1]
            if s != 'nan':
                batch.append(float(s))

Entropy.append(batch)
Entropy = list(map(lambda x: sum(x) * -1, Entropy))

pmma_entropy = 34.98 * 1
dec_entropy = 119.2223 * 100
ec_entropy = 108.4058 * 100

delta_S_mix = list(map(lambda x: (x / (4.2) - (pmma_entropy + dec_entropy+ec_entropy))/1000, Entropy)) # cal/mol K

# %% [markdown]
# ### Enthalpy

# %%
import numpy as np

Enthalpy = []
with open("./MixingPMMA/equilibration/log.lammps", "r") as f:
    for i, line in enumerate(f.readlines()):
        if i >= 4159 and i <= 4189:
            enthalpy = float(line.rsplit()[2])
            Enthalpy.append(enthalpy)



pmma_enthalpy = 233.7869 * 1
dec_enthalpy = 12.789 * 100
ec_enthalpy = 7.1734 * 100

delta_H_mix = list(map(lambda x: x - (pmma_enthalpy + dec_enthalpy+ec_enthalpy), Enthalpy))
delta_H_mix = np.array(delta_H_mix[1:])

# %% [markdown]
# ### Gibbs free energy

# %%
delta_G_mix = np.array(delta_H_mix) - 300 * np.array(delta_S_mix[1:])

# %% [markdown]
# ### Solubility

# %%
delta_H_fus = -160
R = 8.314
T_m = 130 + 273
T = 300
x_sol = np.exp(delta_H_fus / (R* T_m) * (1 - (T / T_m)) - delta_G_mix[-1] / (R*T))
x_sol
# Out:
# 0.02251952129806475

# %% [markdown]
# ### Plot

# %%
fig = go.Figure()

# fig.add_trace(go.Scatter(x=Step[1:], y=list(map(sum, Entropy[1:])), mode='lines', name='Line plot'))
fig.add_trace(go.Scatter(x=Step[1:], y=delta_H_mix, mode='lines+markers', name=r'$\Delta H_{mix}$'))

fig.update_layout(title='PMMA in EC/DEC Mixing v.s Time step\n',
                  title_font=dict(size=50, family='Math'),
                  xaxis=dict(title=r'$ Time step (fs)$',
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                  yaxis=dict(title=r'$Energy(\frac{kcal}{mol})$',
                                    title_font=dict(size=30, family='Math'),
                                    tickfont=dict(size=30, family='Math')),
                legend=dict(
                        font=dict(
                            size=20,  # Setting the font size of the legend
                            family='Courier New',  # Optional: setting the font type
                            color='black'  # Optional: setting the font color
                        ),
                    )
                    )

fig.add_trace(go.Scatter(x=Step[1:], y=np.array(delta_S_mix) * 300, mode='lines+markers', name=r'$T \Delta S_{mix}$'))
fig.add_trace(go.Scatter(x=Step[1:], y=delta_G_mix, mode='lines+markers', name=r'$\Delta G_{mix}$'))



plot_url = py.plot(fig, filename='latex', include_mathjax='cdn')

# %%
from thermo.chemical import Chemical, Mixture
from thermo import solubility
tol = Chemical('toluene')
# tol.rhog,tol.Cpg, tol.kg, tol.mug 
tol.calculate(T=300, P=101325)

mm = Mixture(['water', 'ethanol'], Vfls=[.6, .4], T=300, P=1E5)
solubility.solubility_parameter
# Out:
# <function chemicals.solubility.solubility_parameter(T, Hvapm, Vml)>

# %% [markdown]
# $H_i = \exp\left(\frac{\sum_{\text{j=solvent}} z_j \ln H_{i,j}}
#          {\sum_{\text{j=solvent}} z_j}\right)$

# %% [markdown]
# $\ln x_i^L \gamma_i^L = \frac{\Delta H_{m,i}}{RT}\left(
#         1 - \frac{T}{T_{m,i}}\right) - \frac{\Delta C_{p,i}(T_{m,i}-T)}{RT}
#         + \frac{\Delta C_{p,i}}{R}\ln\frac{T_m}{T}$

# %% [markdown]
# - PMMA Melting point: $130 \degree C$
#
# - PMMA heat capacity at liquid phase:  $4.69 \frac{kJ}{kg \cdot K}$
#
# - PMMA heat capacity at solid phase: $131 \frac{J}{mol \cdot K}$
#
# - PMMA heat of fusion: $1200 \frac{cal}{mol}$

# %%
T = 298.15
Tm = 160 + 273.15
Hm = 1200 * 4.12
Cpl = 4.69 * 120
Cps = 131

solubility.solubility_eutectic(T=T, Tm=Tm, Hm=Hm, Cpl=Cpl, Cps=Cps)
# Out:
# 33.01609258570417
